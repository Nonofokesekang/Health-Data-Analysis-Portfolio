# %% [markdown]
# <a href="https://colab.research.google.com/github/Nonofokesekang/Health-Data-Analysis-Portfolio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
---

## 📊 Current Project: Health Data Exploration

**Notebook:** `01_health_data_exploration.ipynb`

This project uses a small health dataset to practice:
- Cleaning missing values
- Understanding demographic distribution
- Visualizing health trends
- Generating basic insights

---

## 🚀 Goals of This Portfolio

- Build practical experience in health analytics
- Strengthen my Python and data science skills
- Demonstrate my ability to analyze healthcare datasets
- Prepare for entry-level Health Data Analyst roles

---

## 📬 Contact

**Name:** Nonofo Kesekang
**Email:** nonofokesekang@gmail.com
**Location:** Gaborone, Botswana

Feel free to explore the projects and follow my progress!
